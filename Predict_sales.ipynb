# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\Apeksha\Rossmann\train.csv')
# Out:
# C:\Users\Apeksha\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
data.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# 75%    1.000000e+00   0.000000e+00
# max    1.000000e+00   1.000000e+00

# %%
data.dtypes
# Out:
# Store             int64
# DayOfWeek         int64
# Date             object
# Sales             int64
# Customers         int64
# Open              int64
# Promo             int64
# StateHoliday     object
# SchoolHoliday     int64
# dtype: object

# %%
data.StateHoliday.unique()
# Out:
# array(['0', 'a', 'b', 'c', 0], dtype=object)

# %%
data.StateHoliday=data.StateHoliday.astype(str)

# %%
data.StateHoliday.unique()
# Out:
# array(['0', 'a', 'b', 'c'], dtype=object)

# %%
def count_unique(column):
    return len(column.unique())
data.apply(count_unique, axis=0)
# Out:
# Store             1115
# DayOfWeek            7
# Date               942
# Sales            21734
# Customers         4086
# Open                 2
# Promo                2
# StateHoliday         4
# SchoolHoliday        2
# dtype: int64

# %%
data.isnull().any()
# Out:
# Store            False
# DayOfWeek        False
# Date             False
# Sales            False
# Customers        False
# Open             False
# Promo            False
# StateHoliday     False
# SchoolHoliday    False
# dtype: bool

# %%
store_data=data[data.Store==150].sort_values('Date') #sorting sales of store no. 150 by date
plt.figure(figsize=(20,10)) #set figsize to increase size of figure
plt.plot(store_data.Sales.values[:365])

# %%
store_data
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 1016244    150          2  2013-01-01      0          0     0      0
# 1015129    150          3  2013-01-02   6913        762     1      0
# 1014014    150          4  2013-01-03   6391        743     1      0
# 1012899    150          5  2013-01-04   7337        767     1      0
# 1011784    150          6  2013-01-05   6993        736     1      0
# 1010669    150          7  2013-01-06      0          0     0      0
# 1009554    150          1  2013-01-07  11580        978     1      1
# 1008439    150          2  2013-01-08   8619        801     1      1
# 1007324    150          3  2013-01-09   7297        751     1      1
# 1006209    150          4  2013-01-10   7898        776     1      1
# 1005094    150          5  2013-01-11   8291        853     1      1
# 1003979    150          6  2013-01-12   6977        765     1      0
# 1002864    150          7  2013-01-13      0          0     0      0
# 1001749    150          1  2013-01-14   5509        646     1      0
# 1000634    150          2  2013-01-15   5139        597     1      0
# 999519     150          3  2013-01-16   5564        633     1      0
# 998404     150          4  2013-01-17   5876        665     1      0
# 997289     150          5  2013-01-18   6373        695     1      0
# 996174     150          6  2013-01-19   6679        726     1      0
# 995059     150          7  2013-01-20      0          0     0      0
# 993944     150          1  2013-01-21   9668        899     1      1
# 992829     150          2  2013-01-22   8587        788     1      1
# 991714     150          3  2013-01-23   6832        686     1      1
# 990599     150          4  2013-01-24   7657        743     1      1
# 989484     150          5  2013-01-25   7268        747     1      1
# 988369     150          6  2013-01-26   5648        668     1      0
# 987254     150          7  2013-01-27      0          0     0      0
# 986139     150          1  2013-01-28   5103        603     1      0
# 985024     150          2  2013-01-29   5189        556     1      0
# 983909     150          3  2013-01-30   5748        591     1      0
# ...        ...        ...         ...    ...        ...   ...    ...
# 32484      150          4  2015-07-02   9730        864     1      1
# 31369      150          5  2015-07-03  10030        877     1      1
# 30254      150          6  2015-07-04   6873        657     1      0
# 29139      150          7  2015-07-05      0          0     0      0
# 28024      150          1  2015-07-06   8887        840     1      0
# 26909      150          2  2015-07-07   6837        689     1      0
# 25794      150          3  2015-07-08   7233        703     1      0
# 24679      150          4  2015-07-09   8335        789     1      0
# 23564      150          5  2015-07-10   8604        838     1      0
# 22449      150          6  2015-07-11   7390        748     1      0
# 21334      150          7  2015-07-12      0          0     0      0
# 20219      150          1  2015-07-13  12218       1030     1      1
# 19104      150          2  2015-07-14   9631        842     1      1
# 17989      150          3  2015-07-15   9680        826     1      1
# 16874      150          4  2015-07-16  10217        863     1      1
# 15759      150          5  2015-07-17   9544        906     1      1
# 14644      150          6  2015-07-18   7423        725     1      0
# 13529      150          7  2015-07-19      0          0     0      0
# 12414      150          1  2015-07-20   9128        846     1      0
# 11299      150          2  2015-07-21   6977        706     1      0
# 10184      150          3  2015-07-22   7193        686     1      0
# 9069       150          4  2015-07-23   7575        715     1      0
# 7954       150          5  2015-07-24   7281        748     1      0
# 6839       150          6  2015-07-25   7437        759     1      0
# 5724       150          7  2015-07-26      0          0     0      0
# 4609       150          1  2015-07-27  13768       1119     1      1
# 3494       150          2  2015-07-28  10785        904     1      1
# 2379       150          3  2015-07-29  10648        893     1      1
# 1264       150          4  2015-07-30  11755       1048     1      1
# 149        150          5  2015-07-31  10826        975     1      1
#
#         StateHoliday  SchoolHoliday
# 1016244            a              1
# 1015129            0              1
# 1014014            0              1
# 1012899            0              1
# 1011784            0              0
# 1010669            0              0
# 1009554            0              0
# 1008439            0              0
# 1007324            0              0
# 1006209            0              0
# 1005094            0              0
# 1003979            0              0
# 1002864            0              0
# 1001749            0              0
# 1000634            0              0
# 999519             0              0
# 998404             0              0
# 997289             0              0
# 996174             0              0
# 995059             0              0
# 993944             0              0
# 992829             0              0
# 991714             0              0
# 990599             0              0
# 989484             0              0
# 988369             0              0
# 987254             0              0
# 986139             0              0
# 985024             0              0
# 983909             0              0
# ...              ...            ...
# 32484              0              0
# 31369              0              0
# 30254              0              0
# 29139              0              0
# 28024              0              0
# 26909              0              0
# 25794              0              0
# 24679              0              0
# 23564              0              0
# 22449              0              0
# 21334              0              0
# 20219              0              0
# 19104              0              0
# 17989              0              0
# 16874              0              0
# 15759              0              0
# 14644              0              0
# 13529              0              0
# 12414              0              1
# 11299              0              1
# 10184              0              1
# 9069               0              1
# 7954               0              1
# 6839               0              0
# 5724               0              0
# 4609               0              1
# 3494               0              1
# 2379               0              1
# 1264               0              1
# 149                0              1
#
# [942 rows x 9 columns]

# %%
plt.figure(figsize=(20,10))
plt.scatter(x=store_data[data.Open==1].Promo, y=store_data[data.Open==1].Sales, alpha=0.1)
# Out:
# C:\Users\Apeksha\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
#removing unwanted columns
transformed_data=data.drop(['Store','Date','Customers'], axis=1)

# %%
transformed_data.head()
# Out:
#    DayOfWeek  Sales  Open  Promo StateHoliday  SchoolHoliday
# 0          5   5263     1      1            0              1
# 1          5   6064     1      1            0              1
# 2          5   8314     1      1            0              1
# 3          5  13995     1      1            0              1
# 4          5   4822     1      1            0              1

# %%
transformed_data=pd.get_dummies(transformed_data, columns=['DayOfWeek','StateHoliday'])

# %%
#1st prediction. separate dataset into values we want to predict(Sales) and the values to train the algorithm with(DayOfweek, Stateholiday, Promo)
X=transformed_data.drop(['Sales'], axis=1).values
Y=transformed_data.Sales.values
print("The training dataset has {} examples and {} features.".format(X.shape[0], X.shape[1]))
# Out:
# The training dataset has 1017209 examples and 14 features.

# %%
#import Linear Regression and Cross-Validation Models
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
import seaborn as sns
from sklearn import metrics

# %%
X.shape
# Out:
# (1017209, 14)

# %%
Y.shape
# Out:
# (1017209,)

# %%
kfolds = KFold(n_splits=4, shuffle=True, random_state=42)
scores = cross_val_score(lr, X, Y, cv=kfolds)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std()))
# Out:
# Accuracy: 0.55 (+/- 0.00)

# %%
lr=LinearRegression()
X_store = pd.get_dummies(data[data.Store!=150], columns=['DayOfWeek', 'StateHoliday']).drop(['Sales', 'Store', 'Date', 'Customers'], axis=1).values
y_store = pd.get_dummies(data[data.Store!=150], columns=['DayOfWeek', 'StateHoliday']).Sales.values
lm1=lr.fit(X_store, y_store)
Y_Score_predict=lr.predict(pd.get_dummies(store_data,columns=['DayOfWeek', 'StateHoliday']).drop(['Sales', 'Store', 'Date', 'Customers'], axis=1).values)

# %%
plt.figure(figsize=(20, 10))  # Set figsize to increase size of figure
plt.plot(store_data.Sales.values[:365], label="ground truth")
plt.plot(Y_Score_predict[:365], c='r', label="prediction")
plt.legend()
